# %% [markdown]
# <a href="https://colab.research.google.com/github/tapasML/EVAB2_Session_12/blob/main/Session_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Map google drive. Git clone Images. Downgrade scipy for compatibility

# %%
from google.colab import drive
drive.mount( '/content/drive', force_remount=True )
# !git clone https://github.com/seshuad/IMagenet
# !ls 'IMagenet/tiny-imagenet-200/'
# !pip install scipy==1.1.0
# Out:
# Mounted at /content/drive
# Cloning into 'IMagenet'...
# remote: Enumerating objects: 120594, done.
# remote: Total 120594 (delta 0), reused 0 (delta 0), pack-reused 120594
# Receiving objects: 100% (120594/120594), 212.68 MiB | 32.01 MiB/s, done.
# Resolving deltas: 100% (1115/1115), done.
# Checking out files: 100% (120206/120206), done.
# test  train  val  wnids.txt  words.txt
# ...
#      |████████████████████████████████| 31.2MB 78kB/s
# ...
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
import main
from main import *

# %%
loaddata()
# Out:
# starting loading data
# finished loading data, in 52.95065188407898 seconds
# train data shape:  torch.Size([100000, 3, 64, 64])
# train label shape:  torch.Size([100000])
# test data shape:  torch.Size([10000, 3, 64, 64])
# test_labels.shape:  torch.Size([10000])

# %% [markdown]
# Verify dataloader loaded data correctly, by loading few sample images

# %%
displaysampleimage()
# Out:
# shape of images torch.Size([256, 3, 64, 64])
# n02124075 n04067472 n04540053 n04099969

# %% [markdown]
# Define a Resnet18 model and create one (model_resnet.py)

# %%
model = createmodel()

# %% [markdown]
# Display model summary for grayscale image. (training.py)

# %%
modelSummary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 64, 64]           1,728
#        BatchNorm2d-2           [-1, 64, 64, 64]             128
#             Conv2d-3           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-4           [-1, 64, 64, 64]             128
#             Conv2d-5           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#            Dropout-7           [-1, 64, 64, 64]               0
#         BasicBlock-8           [-1, 64, 64, 64]               0
#             Conv2d-9           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-10           [-1, 64, 64, 64]             128
#            Conv2d-11           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-12           [-1, 64, 64, 64]             128
#           Dropout-13           [-1, 64, 64, 64]               0
# ...

# %% [markdown]
# Prepare to train the model. Define loss function, optimizer, scheduler

# %%
definelossfunction()

# %% [markdown]
# Prepare to train the model. Define loss function, optimizer, scheduler

# %%
model = trainmodel()
# Out:
# torch.Size([256, 3, 64, 64]) torch.Size([256]) tensor(181, device='cuda:0') <class 'torch.Tensor'>
# [1,    40] loss: 0.104
# [1,    80] loss: 0.097
# [1,   120] loss: 0.092
# [1,   160] loss: 0.089
# [1,   200] loss: 0.086
# [1,   240] loss: 0.083
# [1,   280] loss: 0.082
# [1,   320] loss: 0.080
# [1,   360] loss: 0.078
# correct /processed = 9205 100000
# Epoch = 0, Training Accuracy:  9.21, Test Accuracy: 15.00
# torch.Size([256, 3, 64, 64]) torch.Size([256]) tensor(5, device='cuda:0') <class 'torch.Tensor'>
# [2,    40] loss: 0.075
# [2,    80] loss: 0.074
# [2,   120] loss: 0.073
# [2,   160] loss: 0.071
# [2,   200] loss: 0.070
# [2,   240] loss: 0.069
# [2,   280] loss: 0.068
# [2,   320] loss: 0.067
# [2,   360] loss: 0.065
# correct /processed = 20674 100000
# Epoch = 1, Training Accuracy:  20.67, Test Accuracy: 24.78
# torch.Size([256, 3, 64, 64]) torch.Size([256]) tensor(193, device='cuda:0') <class 'torch.Tensor'>
# [3,    40] loss: 0.063
# [3,    80] loss: 0.063
# ...
